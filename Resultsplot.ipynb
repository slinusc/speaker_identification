# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

res = pd.read_csv('./final_results_Cnn_logReg.csv')

# %%
res
# Out:
#    Layer  Train Loss  Train Accuracy  Test Accuracy Total  \
# 0      0    0.231033        0.906554             0.940684
# 1      5    0.616142        0.753352             0.946381
# 2     10    0.719348        0.716034             0.888367
# 3     15    0.878888        0.646970             0.841435
# 4     20    0.654833        0.738058             0.890934
# 5     24    1.588694        0.405231             0.772042
#
#    Test Precision Total  Test Recall Total  Test F1-Score Total  \
# 0              0.951647           0.940684             0.939705
# 1              0.948513           0.946381             0.944384
# 2              0.887520           0.888367             0.884036
# 3              0.858768           0.841435             0.831458
# 4              0.901040           0.890934             0.889333
# 5              0.757648           0.772042             0.727643
#
#    Test Accuracy Male  Test Precision Male  Test Recall Male  \
# 0            0.992563             0.992741          0.992563
# 1            0.991886             0.995264          0.991886
# 2            0.958136             0.965260          0.958136
# 3            0.926401             0.947633          0.926401
# 4            0.950545             0.960865          0.950545
# 5            0.899388             0.936012          0.899388
#
#    Test F1-Score Male  Test Accuracy Female  Test Precision Female  \
# 0            0.992565              0.889701               0.913237
# 1            0.993565              0.901661               0.906429
# 2            0.961057              0.819574               0.841523
# 3            0.935479              0.757656               0.800296
# 4            0.953622              0.836436               0.861276
# 5            0.901832              0.648148               0.621560
#
#    Test Recall Female  Test F1-Score Female
# 0            0.889701              0.888748
# 1            0.901661              0.897935
# 2            0.819574              0.823494
# 3            0.757656              0.740201
# 4            0.836436              0.837684
# 5            0.648148              0.577861

# %%
plt.figure(figsize=(10, 5))
plt.plot(res['Layer'], res["Test Accuracy Total"], marker='o', color='b', label='All Speakers')
plt.plot(res['Layer'], res["Test Accuracy Female"], marker='o', color='g', label='Female Speakers')
plt.plot(res['Layer'], res["Test Accuracy Male"], marker='o', color='m', label='Male Speakers')
plt.xlabel('Layer')
plt.ylabel('Accuracy')
plt.title('Accuracy of Speaker Identification for Different Layers in XLS-R with CNN')
plt.ylim(0.6, 1)  # Set y-axis range from 0 to 1
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 5))
plt.plot(res['Layer'], res["Test F1-Score Total"], marker='o', color='b', label='All Speakers')
plt.plot(res['Layer'], res["Test F1-Score Female"], marker='o', color='g', label='Female Speakers')
plt.plot(res['Layer'], res["Test F1-Score Male"], marker='o', color='m', label='Male Speakers')
plt.xlabel('Layer')
plt.ylabel('F1-Score')
plt.title('F1-Score of Speaker Identification for Different Layers in XLS-R with CNN')
plt.ylim(0.6, 1)  # Set y-axis range from 0 to 1
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
resLog = pd.read_csv('./final_results_logReg.csv')
resLog
# Out:
#    Layer  Test Accuracy Total  Test Precision Total  Test Recall Total  \
# 0      0             0.955094              0.955222           0.955094
# 1      5             0.975871              0.976278           0.975871
# 2     10             0.932953              0.933169           0.932953
# 3     15             0.933624              0.933594           0.933624
# 4     20             0.954845              0.955242           0.954845
# 5     24             0.847804              0.849081           0.847804
#
#    Test F1-Score Total  Test Accuracy Male  Test Precision Male  \
# 0             0.954982            0.990534             0.994573
# 1             0.975963            0.998648             0.998657
# 2             0.932663            0.972991             0.984431
# 3             0.933253            0.976367             0.983795
# 4             0.954505            0.986182             0.991992
# 5             0.847788            0.909585             0.936091
#
#    Test Recall Male  Test F1-Score Male  Test Accuracy Female  \
# 0          0.990534            0.992535              0.920266
# 1          0.998648            0.998647              0.953488
# 2          0.972991            0.978543              0.893475
# 3          0.976367            0.979979              0.891478
# 4          0.986182            0.989018              0.926197
# 5          0.909585            0.922120              0.787698
#
#    Test Precision Female  Test Recall Female  Test F1-Score Female
# 0               0.924232            0.920266              0.921878
# 1               0.956245            0.953488              0.954658
# 2               0.902529            0.893475              0.897299
# 3               0.899974            0.891478              0.895131
# 4               0.935831            0.926197              0.930007
# 5               0.816348            0.787698              0.800693

# %%
plt.figure(figsize=(10, 5))
plt.plot(resLog['Layer'], resLog["Test Accuracy Total"], marker='o', color='b', label='All Speakers')
plt.plot(resLog['Layer'], resLog["Test Accuracy Female"], marker='o', color='g', label='Female Speakers')
plt.plot(resLog['Layer'], resLog["Test Accuracy Male"], marker='o', color='m', label='Male Speakers')
plt.xlabel('Layer')
plt.ylabel('Accuracy')
plt.title('Accuracy of Speaker Identification for Different Layers in XLS-R with Logistic Regression')
plt.ylim(0.6, 1)   # Set y-axis range from 0 to 1
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 5))
plt.plot(resLog['Layer'], resLog["Test F1-Score Total"], marker='o', color='b', label='All Speakers')
plt.plot(resLog['Layer'], resLog["Test F1-Score Female"], marker='o', color='g', label='Female Speakers')
plt.plot(resLog['Layer'], resLog["Test F1-Score Male"], marker='o', color='m', label='Male Speakers')
plt.xlabel('Layer')
plt.ylabel('F1-Score')
plt.title('F1-Score of Speaker Identification for Different Layers in XLS-R with Logistic Regression')
plt.ylim(0.6, 1)   # Set y-axis range from 0 to 1
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
